# %%
import matplotlib.pyplot as plt
x = list(range(100))
y = x*3

for i in range(100):
    plt.scatter(x[i], y[i], color='b')
    plt.draw()
    plt.pause(0.1)
    plt.clf()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       6 plt.scatter(x[i], y[i], color='b')
#       7 plt.draw()
# ----> 8 plt.pause(0.1)
#
# File c:\Users\ianmi\miniconda3\envs\GPUtorch\lib\site-packages\matplotlib\pyplot.py:557, in pause(interval)
#     555         canvas.draw_idle()
#     556     show(block=False)
# --> 557     canvas.start_event_loop(interval)
#     558 else:
#     559     time.sleep(interval)
#
# File c:\Users\ianmi\miniconda3\envs\GPUtorch\lib\site-packages\matplotlib\backend_bases.py:2517, in FigureCanvasBase.start_event_loop(self, timeout)
#    2515 while self._looping and counter * timestep < timeout:
#    2516     self.flush_events()
# -> 2517     time.sleep(timestep)
#    2518     counter += 1
#
# KeyboardInterrupt:
